# %% [markdown]
# ### Functions include:
# (1) show missing data percentage in all columns
#
# (2) remove missing data percentage >= 70% columns
#
# (3) sort date frame time
#
# (4) imputation

# %% [markdown]
# ## (1) Functions

# %%
import pandas as pd
import numpy as np

# %%
def show_col_missing_data_percentage(pd1_1):
    col_name = list(pd1_1.columns.values)
    j = 0
    for i in col_name:
        # count number of rows with missing values
        n_miss = pd1_1[[i]].isnull().sum()
        perc = n_miss / pd1_1.shape[0] * 100
        print('> %d, Missing: %d (%.1f%%) -> %s' % (
            j, n_miss, perc, i))
        j = j+1

# %%
def remove_missing_data_columns(pd1_1, missing_percent_threshold):
    percent_missing = pd1_1.isnull().sum() * 100 / len(pd1_1)
    missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
    remove_cols = []
    for i in range(0, missing_value_df.shape[0]):
        if missing_value_df.iloc[i, 0] >= missing_percent_threshold:
            remove_cols.append(i)
    pd1_2 = pd1_1.drop(pd1_1.columns[remove_cols], axis=1) 
    
    pd1_2.loc[pd1_2['IS_MALE'] == False, 'IS_MALE'] = "F"
    pd1_2.loc[pd1_2['IS_MALE'] == True, 'IS_MALE'] = "M"
    pd1_2.rename({'IS_MALE': 'GENDER'}, axis=1, inplace=True)
    
    pd1_cols1 = pd1_2.columns.tolist()
    pd1_cols2 = pd1_cols1[0:3]+pd1_cols1[4:]
    pd1_3 = pd1_2[pd1_cols2]
    return pd1_3

# %%
def sort_df_time(pd1):
    hadm_id_g = pd1.groupby('HADM_ID')
    hadm_id_g_size_count = hadm_id_g.size().reset_index(
        name='counts')
    hadm_id_arr = hadm_id_g_size_count['HADM_ID'].to_numpy() 
    append_dfs = []
    
    for i in range(0, len(hadm_id_arr)):
        g = hadm_id_g.get_group(hadm_id_arr[i])
        g2 = g.sort_values(by=['WINDOW_START'])
        append_dfs.append(g2)
    pd2 = pd.concat(append_dfs)
    return pd2

# %%
from sklearn.experimental import enable_iterative_imputer  
from sklearn.impute import IterativeImputer

def impute_data(input_df):
    input_df = input_df.reset_index(drop=True)   
    pd1_1 = input_df.iloc[:, 0:6] 
    pd2_1 = input_df.iloc[:, 6:] 
    X = pd2_1.values
    imputer = IterativeImputer(sample_posterior=True)
    imputer.fit(X)
    Xtrans = imputer.transform(X)
    Xtrans_df = pd.DataFrame(Xtrans)
    col_name2 = list(pd2_1.columns.values)
    Xtrans_df.columns = col_name2
    final_df2 = pd.concat([pd1_1, Xtrans_df], axis=1)
    return final_df2

# %% [markdown]
# ## (2) Execute functions

# %%
m3 = '2_mimic3_6tw_6ts.csv'
m3_1 = pd.read_csv(m3)
m3_2 = remove_missing_data_columns(m3_1, 70)
m3_3 = sort_df_time(m3_2)
m3_3
# Out:
#         HADM_ID         WINDOW_START           WINDOW_END  AKI_IN_ENCOUNTER  \
# 0        100001  2117-09-11 08:22:00  2117-09-11 14:22:00              True
# 1        100001  2117-09-11 14:22:00  2117-09-11 20:22:00              True
# 2        100001  2117-09-11 20:22:00  2117-09-12 02:22:00              True
# 3        100001  2117-09-12 02:22:00  2117-09-12 08:22:00              True
# 4        100001  2117-09-12 08:22:00  2117-09-12 14:22:00              True
# ...         ...                  ...                  ...               ...
# 838833   181266  2198-05-06 20:07:00  2198-05-07 02:07:00             False
# 838834   181266  2198-05-07 02:07:00  2198-05-07 08:07:00             False
# 838835   181269  2126-07-25 12:10:00  2126-07-25 18:10:00              True
# 838836   181269  2126-07-25 18:10:00  2126-07-26 00:10:00              True
# 838837   181269  2126-07-26 00:10:00  2126-07-26 06:10:00              True
#
#         AGE GENDER   BUN    pH    PT   MCV  ...  Calcium, Total  Anion Gap  \
# 0        35      F   NaN   NaN  12.1  80.0  ...             NaN        NaN
# 1        35      F   NaN   NaN  12.1  82.0  ...            8.85       18.0
# 2        35      F   NaN   NaN  12.1  82.0  ...            7.00       16.0
# 3        35      F   NaN   NaN  12.1  81.0  ...            9.20       13.0
# 4        35      F   NaN   NaN  12.1  81.0  ...            9.20       13.0
# ...     ...    ...   ...   ...   ...   ...  ...             ...        ...
# 838833   58      M   NaN   NaN  13.9  81.0  ...            8.50       16.0
# 838834   58      M   NaN   NaN  13.5  84.0  ...            8.50       13.0
# 838835   41      M  12.0   NaN  12.1  81.0  ...            9.10       14.0
# 838836   41      M  12.0   NaN  12.1  81.0  ...            9.10       14.0
# 838837   41      M  15.0  7.37  12.4  79.0  ...            9.10       15.0
#
#         Potassium  Lactate  Bilirubin, Total  Creatinine  Phosphate  INR(PT)  \
# 0             4.9      1.9               0.5        2.60        NaN      1.0
# 1             4.2      1.9               0.5        2.35       3.05      1.0
# 2             4.1      1.9               0.5        2.30       2.50      1.0
# 3             3.8      1.9               0.5        2.20       2.80      1.0
# 4             3.8      1.9               0.5        2.20       2.80      1.0
# ...           ...      ...               ...         ...        ...      ...
# 838833        3.6      NaN               NaN        0.70       2.90      1.3
# 838834        3.9      NaN               NaN        0.80       2.90      1.2
# 838835        3.4      NaN               0.3        0.70       3.90      1.0
# 838836        4.0      NaN               0.3        0.70       3.90      1.0
# 838837        3.9      NaN               0.3        0.70       4.20      1.1
#
#          PTT   RDW
# 0       27.0  13.6
# 1       27.0  14.3
# 2       27.0  14.3
# 3       27.0  13.9
# 4       27.0  13.9
# ...      ...   ...
# 838833  28.7  14.9
# 838834  29.5  14.9
# 838835  24.0  13.5
# 838836  26.9  13.5
# 838837  38.8  13.3
#
# [838838 rows x 24 columns]

# %%
m3 = '2_mimic3_6tw_6ts.csv'
m3_1 = pd.read_csv(m3)
m3_2 = remove_missing_data_columns(m3_1, 70)
m3_3 = sort_df_time(m3_2)
m3_4 = impute_data(m3_3)

# %%
m4 = '2_mimic4_6tw_6ts.csv'
m4_1 = pd.read_csv(m4)
m4_2 = remove_missing_data_columns(m4_1, 70)
m4_3 = sort_df_time(m4_2)
m4_4 = impute_data(m4_3)

# %%
eicu = '2_eicu_6tw_6ts.csv'
eicu_1 = pd.read_csv(eicu)
eicu_2 = remove_missing_data_columns(eicu_1, 70)
eicu_3 = sort_df_time(eicu_2)
eicu_4 = impute_data(eicu_3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 5>()
#       3 eicu_2 = remove_missing_data_columns(eicu_1, 70)
#       4 eicu_3 = sort_df_time(eicu_2)
# ----> 5 eicu_4 = impute_data(eicu_3)
#
# Input In [5], in impute_data(input_df)
#       8 X = pd2_1.values
#       9 imputer = IterativeImputer(sample_posterior=True)
# ---> 10 imputer.fit(X)
#      11 Xtrans = imputer.transform(X)
#      12 Xtrans_df = pd.DataFrame(Xtrans)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:775, in IterativeImputer.fit(self, X, y)
#     758 def fit(self, X, y=None):
#     759     """Fit the imputer on `X` and return self.
#     760
#     761     Parameters
#    (...)
#     773         Fitted estimator.
#     774     """
# --> 775     self.fit_transform(X)
#     776     return self
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:664, in IterativeImputer.fit_transform(self, X, y)
#     660 for feat_idx in ordered_idx:
#     661     neighbor_feat_idx = self._get_neighbor_feat_idx(
#     662         n_features, feat_idx, abs_corr_mat
#     663     )
# --> 664     Xt, estimator = self._impute_one_feature(
#     665         Xt,
#     666         mask_missing_values,
#     667         feat_idx,
#     668         neighbor_feat_idx,
#     669         estimator=None,
#     670         fit_mode=True,
#     671     )
#     672     estimator_triplet = _ImputerTriplet(
#     673         feat_idx, neighbor_feat_idx, estimator
#     674     )
#     675     self.imputation_sequence_.append(estimator_triplet)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/impute/_iterative.py:345, in IterativeImputer._impute_one_feature(self, X_filled, mask_missing_values, feat_idx, neighbor_feat_idx, estimator, fit_mode)
#     342     b = (self._max_value[feat_idx] - mus) / sigmas
#     344     truncated_normal = stats.truncnorm(a=a, b=b, loc=mus, scale=sigmas)
# --> 345     imputed_values[inrange_mask] = truncated_normal.rvs(
#     346         random_state=self.random_state_
#     347     )
#     348 else:
#     349     imputed_values = estimator.predict(X_test)
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py:473, in rv_frozen.rvs(self, size, random_state)
#     471 kwds = self.kwds.copy()
#     472 kwds.update({'size': size, 'random_state': random_state})
# --> 473 return self.dist.rvs(*self.args, **kwds)
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py:1092, in rv_generic.rvs(self, *args, **kwds)
#    1090     vals = self._rvs(*args)
#    1091 else:
# -> 1092     vals = self._rvs(*args, size=size, random_state=random_state)
#    1094 vals = vals * scale + loc
#    1096 # do not forget to restore the _random_state
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:8299, in truncnorm_gen._rvs(self, a, b, size, random_state)
#    8287     while not it.finished:
#    8288         # Convert the iterator's multi_index into an index into the
#    8289         # `out` array where the call to _rvs_scalar() will be stored.
#    (...)
#    8295         # bc[j] will be True in those cases where it.multi_index[j]
#    8296         # would cause an IndexError.
#    8297         idx = tuple((it.multi_index[j] if not bc[j] else slice(None))
#    8298                     for j in range(-len(size), 0))
# -> 8299         out[idx] = self._rvs_scalar(it[0], it[1], numsamples,
#    8300                                     random_state).reshape(shp)
#    8301         it.iternext()
#    8303 if size == ():
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:8316, in truncnorm_gen._rvs_scalar(self, a, b, numsamples, random_state)
#    8314 # Calculate some rvs
#    8315 U = random_state.uniform(low=0, high=1, size=N)
# -> 8316 x = self._ppf(U, a, b)
#    8317 rvs = np.reshape(x, size1d)
#    8318 return rvs
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:8190, in truncnorm_gen._ppf(self, q, a, b)
#    8188 a, b = np.atleast_1d(a), np.atleast_1d(b)
#    8189 if a.size == 1 and b.size == 1:
# -> 8190     return _truncnorm_ppf_scalar(q, a.item(), b.item())
#    8192 out = None
#    8193 it = np.nditer([q, a, b, out], [],
#    8194                [['readonly'], ['readonly'], ['readonly'],
#    8195                 ['writeonly', 'allocate']])
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:8007, in _truncnorm_ppf_scalar(q, a, b)
#    8005 q = np.atleast_1d(q)
#    8006 out = np.zeros(np.shape(q))
# -> 8007 condle0, condge1 = (q <= 0), (q >= 1)
#    8008 if np.any(condle0):
#    8009     out[condle0] = a
#
# KeyboardInterrupt:

# %%
e_c2 = eicu_4.columns.values.tolist()
m3_c2 = m3_4.columns.values.tolist()
common_ele1 = np.array(list(set(e_c2).intersection(m3_c2)))
m4_c2 = m4_4.columns.values.tolist()
common_eles = np.array(list(set(common_ele1).intersection(m4_c2)))

# %%
common_eles

# %%
common_eles2 = ['HADM_ID', 'WINDOW_START', 'WINDOW_END', 
                'AKI_IN_ENCOUNTER', 'GENDER', 'AGE',
                'Potassium', 'MCV', 'Sodium', 'Calcium, Total', 
                'Phosphate', 'Magnesium', 'INR(PT)', 'RDW', 
                'Anion Gap', 'PT', 'pH', 'BUN', 'Lactate', 
                'Creatinine', 'Bilirubin, Total', 'PTT']

# %%
eicu_5 = eicu_4[common_eles2]
m3_5 = m3_4[common_eles2]
m4_5 = m4_4[common_eles2]

# %%
m4_5
# Out:
#           HADM_ID         WINDOW_START           WINDOW_END  AKI_IN_ENCOUNTER  \
# 0        20000094  2150-03-02 15:34:00  2150-03-02 21:34:00             False
# 1        20000094  2150-03-02 21:34:00  2150-03-03 03:34:00             False
# 2        20000094  2150-03-03 03:34:00  2150-03-03 09:34:00             False
# 3        20000147  2121-08-30 16:30:00  2121-08-30 22:30:00             False
# 4        20000147  2121-08-30 22:30:00  2121-08-31 04:30:00             False
# ...           ...                  ...                  ...               ...
# 2143334  29999625  2157-11-08 00:00:00  2157-11-08 06:00:00              True
# 2143335  29999828  2180-10-28 08:15:00  2180-10-28 14:15:00             False
# 2143336  29999828  2180-10-28 14:15:00  2180-10-28 20:15:00             False
# 2143337  29999828  2180-10-28 20:15:00  2180-10-29 02:15:00             False
# 2143338  29999828  2180-10-29 02:15:00  2180-10-29 08:15:00             False
#
#         GENDER  AGE  Potassium        MCV     Sodium  Calcium, Total  ...  \
# 0            M   79   4.600000  86.000000  133.00000        9.300000  ...
# 1            M   79   4.600000  86.000000  133.00000        9.300000  ...
# 2            M   79   4.300000  89.000000  127.00000        7.800000  ...
# 3            M   71   4.056098  90.333333  141.76538        7.840302  ...
# 4            M   71   4.600000  91.000000  134.00000        8.707846  ...
# ...        ...  ...        ...        ...        ...             ...  ...
# 2143334      M   69   4.100000  86.000000  149.00000        8.600000  ...
# 2143335      M   47   4.700000  90.000000  135.00000        8.700000  ...
# 2143336      M   47   4.700000  90.000000  135.00000        8.700000  ...
# 2143337      M   47   4.700000  90.000000  135.00000        8.700000  ...
# 2143338      M   47   4.300000  89.000000  137.00000        8.800000  ...
#
#           INR(PT)        RDW  Anion Gap         PT     pH   BUN   Lactate  \
# 0        1.700000  20.500000       25.0  18.200000  7.410  99.0  4.000000
# 1        1.700000  20.500000       25.0  18.200000  7.360  99.0  4.500000
# 2        2.000000  20.400000       25.0  22.100000  7.340  99.0  6.900000
# 3        1.266667  12.233333       17.0  13.733333  7.375  12.0  1.475000
# 4        1.266667  12.400000       14.0  13.733333  7.390  13.0  1.900000
# ...           ...        ...        ...        ...    ...   ...       ...
# 2143334  1.200000  14.600000       15.0  13.200000  7.410  21.0  1.300000
# 2143335  1.100000  13.600000       12.0  11.800000  7.270  13.0  2.368009
# 2143336  1.100000  13.600000       12.0  11.800000  7.270  13.0  1.074661
# 2143337  1.100000  13.600000       12.0  11.800000  7.270  13.0  1.522087
# 2143338  1.100000  13.700000       11.0  11.800000  7.420  10.0  1.588239
#
#          Creatinine  Bilirubin, Total        PTT
# 0               3.8          2.500000  37.400000
# 1               3.8          2.500000  37.400000
# 2               3.9          2.700000  40.200000
# 3               0.7         -3.179305  66.733333
# 4               0.7          1.942723  66.733333
# ...             ...               ...        ...
# 2143334         1.6         -2.325518  25.400000
# 2143335         0.9          2.374469  28.100000
# 2143336         0.9          1.281016  28.100000
# 2143337         0.9         -1.088781  28.100000
# 2143338         0.8          0.600000  28.100000
#
# [2143339 rows x 22 columns]

# %%
m3_5.to_csv("3_mimic3_6tw_6ts_imputed.csv", index=False)
m4_5.to_csv("3_mimic4_6tw_6ts_imputed.csv", index=False)
eicu_5.to_csv("3_eicu_6tw_6ts_imputed.csv", index=False)
